# %%
import pyupbit
import numpy as np

# %%
# OHLCV(open, high, low, close, volume)로 당일 시가, 고가, 저가, 종가, 거래량에 대한 데이터
df = pyupbit.get_ohlcv("KRW-BTC", count=365) # OHLCV during 7 days

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 365 entries, 2022-08-14 09:00:00 to 2023-08-13 09:00:00
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    365 non-null    float64
#  1   high    365 non-null    float64
#  2   low     365 non-null    float64
#  3   close   365 non-null    float64
#  4   volume  365 non-null    float64
#  5   value   365 non-null    float64
# dtypes: float64(6)
# memory usage: 20.0 KB

# %%
# 변동폭 * k 계산, (고가 - 저가) * k값
df['range'] = (df['high'] - df['low']) * 0.5

# target(매수가), range 컬럼을 한칸씩 밑으로 내림(.shift(1))
df['target'] = df['open'] + df['range'].shift(1)

# ror(수익률), np.where(조건문, 참일때 값, 거짓일때 값)
df['ror'] = np.where(df['high'] > df['target'],
                     df['close'] / df['target'],
                     1)

# 누적 곱 계산(cumprod) => 누적 수익률  HPR(Holding Period Return)
df['hpr'] = df['ror'].cumprod()

# Draw Down 계산 (누적 최대 값과 현재 hpr 차이 / 누적 최대값 * 100)
df['dd'] = (df['hpr'].cummax() - df['hpr']) / df['hpr'].cummax() * 100

#MDD 계산
print("MDD(%): ", df['dd'].max())

#엑셀로 출력
# df.to_excel("dd.xlsx")
# Out:
# MDD(%):  23.383432317307584

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 365 entries, 2022-08-14 09:00:00 to 2023-08-13 09:00:00
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    365 non-null    float64
#  1   high    365 non-null    float64
#  2   low     365 non-null    float64
#  3   close   365 non-null    float64
#  4   volume  365 non-null    float64
#  5   value   365 non-null    float64
#  6   range   365 non-null    float64
#  7   target  364 non-null    float64
#  8   ror     365 non-null    float64
#  9   hpr     365 non-null    float64
#  10  dd      365 non-null    float64
# dtypes: float64(11)
# memory usage: 34.2 KB

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df['close'].plot()
# Out:
# <Axes: >

# %%
df['dd'].plot()
# Out:
# <Axes: >

# %%
df.tail()
# Out:
#                            open        high         low       close  \
# 2023-08-09 09:00:00  39437000.0  39850000.0  39076000.0  39209000.0
# 2023-08-10 09:00:00  39209000.0  39397000.0  39010000.0  39119000.0
# 2023-08-11 09:00:00  39119000.0  39410000.0  39050000.0  39233000.0
# 2023-08-12 09:00:00  39233000.0  39316000.0  39099000.0  39283000.0
# 2023-08-13 09:00:00  39283000.0  39330000.0  39215000.0  39262000.0
#
#                           volume         value     range      target  \
# 2023-08-09 09:00:00  3299.568675  1.303051e+11  387000.0  39942000.0
# 2023-08-10 09:00:00  2713.945532  1.063589e+11  193500.0  39596000.0
# 2023-08-11 09:00:00  1877.912104  7.358262e+10  180000.0  39312500.0
# 2023-08-12 09:00:00  1450.679978  5.693093e+10  108500.0  39413000.0
# 2023-08-13 09:00:00   511.894622  2.010714e+10   57500.0  39391500.0
#
#                           ror       hpr        dd
# 2023-08-09 09:00:00  1.000000  0.941660  7.686186
# 2023-08-10 09:00:00  1.000000  0.941660  7.686186
# 2023-08-11 09:00:00  0.997978  0.939756  7.872868
# 2023-08-12 09:00:00  1.000000  0.939756  7.872868
# 2023-08-13 09:00:00  1.000000  0.939756  7.872868

# %%
plot
